# %% [markdown]
# # Тема: "Парсинг данных. HTML, Beautiful Soap"

# %% [markdown]
# ### Задание 1
#
# Необходимо собрать информацию о вакансиях на вводимую должность (используем **input** или через аргументы получаем должность) с сайтов **HeadHanter** (обязательно) и/или **Superjob** (по желанию).
#
# Приложение должно анализировать несколько страниц сайта (также вводим через **input** или аргументы). Получившийся список должен содержать в себе минимум:
#
# * Наименование вакансии.
#
# * Предлагаемую зарплату (разносим в три поля: минимальная и максимальная и валюта. цифры преобразуем к цифрам).
#
# * Ссылку на саму вакансию.
#
# * Сайт, откуда собрана вакансия.
#
# По желанию можно добавить ещё параметры вакансии (например, работодателя и расположение). Структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью **DataFrame** через **Pandas**. Сохраните результат в файл **json** либо **csv**.

# %% [markdown]
# #### Ответ:

# %%
# Импорт нужных библиотек:
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
# Обозначение URL сайтов:

# HeadHanter:
URL_HH = 'https://hh.ru/search/vacancy'

# SuperJob:
HOST_SJ = 'https://www.superjob.ru'
URL_SJ = 'https://www.superjob.ru/vacancy/search'

# %%
# Устновка User-Agent:
HEADER = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
          AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'}

# %%
# Функция запроса HTML-страницы по URL сайта:
def get_html(url, params=''):
    response = requests.get(url, headers = HEADER, params = params)
    
    return response

# %%
# Функция запроса контента с HTML-страницы HeadHanter:
def get_hh_content(response):
    soup = bs(response, 'lxml')
    items = soup.find_all('div', class_ = 'serp-item')
    
    hh_vacancy = []
    for item in items:
        hh_vacancy.append(
            {'site': 'HeadHanter', # Название сайта
             'title': item.find('a', {'class': 'serp-item__title'}).get_text(), # Название вакансии
             'link': item.find('a', {'class': 'serp-item__title'})['href'], # Ссылка на вакансию
             'salary': item.find('span', {'data-qa': 'vacancy-serp__vacancy-compensation'}), # Зарплата
             'city': item.find('div', {'data-qa': 'vacancy-serp__vacancy-address'}).contents[0].strip(', '), # Город
             'organization': item.find('a', {'class': 'bloko-link_kind-tertiary'}), # Название компании
             'note': item.find('div', {'class': 'vacancy-serp-item__label'})}) # Примечание

    # Упорядочение полученных данных:
    for i in hh_vacancy:
        # Salary
        try:
            i['salary'] = i['salary'].text
        except:
            i['salary'] = None
        if i['salary']:
            salary_list = i['salary'].split(' ')
            if salary_list[0] == 'от':
                i['salary_min'] = salary_list[1]
                i['salary_max'] = None
            elif salary_list[0] == 'до':
                i['salary_min'] = None
                i['salary_max'] = salary_list[1]
            else:
                i['salary_min'] = salary_list[0]
                i['salary_max'] = salary_list[2]
            i['salary_currency'] = salary_list[-1]
        else:
            i['salary_min'] = None
            i['salary_max'] = None
            i['salary_currency'] = None
        i.pop('salary')
        # City
        if i['city']:
            city_list = i['city'].split(',')
            i['city'] = city_list[0]
        # Organization
        if i['organization'] != None:
            i['organization'] = i['organization'].get_text()
        # Note
        if i['note'] != None:
            i['note'] = i['note'].get_text()
    
    return hh_vacancy

# %%
# Главная функция парсинга сайта HeadHanter:
def parser_hh():
    post = str(input('Введите название вакансий для парсинга: '))
    pages = int(input('Введите количество страниц для парсинга: '))
    html = get_html(URL_HH)
    
    if html.status_code == 200:
        vacancy = []
        for page in range(1, pages + 1):
            print(f'Парсится hh, страница: {page}')
            html = get_html(URL_HH, params = {'text': post, 'page': page})
            vacancy.extend(get_hh_content(html.text))
        hh_result = pd.DataFrame(vacancy)
    
    else:
        hh_result = html.status_code
    
    return hh_result

parser_hh()
# Out:
# Введите название вакансий для парсинга: Разработчик Python
# Введите количество страниц для парсинга: 2
# Парсится hh, страница: 1
# Парсится hh, страница: 2
#           site                                              title  \
# 0   HeadHanter                                 Программист Python
# 1   HeadHanter                        Python разработчик (Django)
# 2   HeadHanter                                 Программист Python
# 3   HeadHanter                   Senior Python developer (Django)
# 4   HeadHanter                            Middle Python Developer
# 5   HeadHanter                                 Разработчик Python
# 6   HeadHanter  Python разработчик на внутренний проект (удалё...
# 7   HeadHanter                                    Python Engineer
# 8   HeadHanter       Разработчик Python (искусственный интеллект)
# 9   HeadHanter                        Программист Python (middle)
# 10  HeadHanter                    Middle Backend Python Developer
# 11  HeadHanter                   Middle Python developer (Казань)
# 12  HeadHanter                      Python разработчик (удалённо)
# 13  HeadHanter                                 Разработчик Python
# 14  HeadHanter                                 Разработчик Python
# 15  HeadHanter                        Разработчик бэкэнд (Python)
# 16  HeadHanter           Разработчик (Backend developer / Python)
# 17  HeadHanter             Backend-разработчик / Python developer
# 18  HeadHanter                                   Python developer
# 19  HeadHanter                                 Разработчик Python
# 20  HeadHanter                   Sr Python разработчик (удаленно)
# 21  HeadHanter                        Разработчик Python (Middle)
# 22  HeadHanter                         Ведущий программист Python
# 23  HeadHanter                                 Python разработчик
# 24  HeadHanter                                 Python программист
# 25  HeadHanter                               С++/Python Developer
# 26  HeadHanter          Senior Python разработчик (бэк, удаленно)
# 27  HeadHanter                  Senior Backend Developer (Python)
# 28  HeadHanter                   Senior Python developer (Django)
# 29  HeadHanter                    Senior Python developer (MLOps)
# 30  HeadHanter                             С++ Developer (Python)
# 31  HeadHanter               Python Engineer / Разработчик Python
# 32  HeadHanter  Инженер-программист / Бэкенд-разработчик на Py...
# 33  HeadHanter                                   Python Developer
# 34  HeadHanter                          Разработчик Python midlle
# 35  HeadHanter                         Разработчик Python, Django
# 36  HeadHanter                    Python-разработчик систем сбора
# 37  HeadHanter                          Разработчик Python Junior
# 38  HeadHanter  Программист-разработчик (Junior backend - разр...
# 39  HeadHanter                                 Разработчик Python
#
#                                                  link                city  \
# 0   https://vladivostok.hh.ru/vacancy/76331573?fro...     Санкт-Петербург
# 1   https://vladivostok.hh.ru/vacancy/76661153?fro...     Санкт-Петербург
# 2   https://vladivostok.hh.ru/vacancy/76785097?fro...              Москва
# 3   https://vladivostok.hh.ru/vacancy/76821518?fro...              Турция
# 4   https://vladivostok.hh.ru/vacancy/76820856?fro...              Москва
# 5   https://vladivostok.hh.ru/vacancy/76433537?fro...              Москва
# 6   https://vladivostok.hh.ru/vacancy/77013948?fro...              Москва
# 7   https://vladivostok.hh.ru/vacancy/76983666?fro...                Баку
# 8   https://vladivostok.hh.ru/vacancy/77038946?fro...              Москва
# 9   https://vladivostok.hh.ru/vacancy/75719539?fro...                Орел
# 23                               Own Script                       None
# 24                                  NETRIKA                       None
# 25                              ООО Стратус              Можно из дома
# 26  Франчайзинговая розничная сеть Галамарт              Можно из дома
# 27                        ООО Retail Rocket              Можно из дома
# 28                                evrone.ru              Можно из дома
# 29                                 Wisebits  Откликнитесь среди первых
# 30                          ООО МКО Системы                       None
# 31                        AliExpress Россия                       None
# 32            АО Омский НИИ Приборостроения                       None
# 33                                   Компэл              Можно из дома
# 34                               ГРЧЦ, ФГУП                       None
# 35                                     None                       None
# 36                              ООО Селфсек              Можно из дома
# 37                               ООО Нумеди                       None
# 38                            ТОО Faceplate                       None
# 39                           ПАО Ростелеком  Откликнитесь среди первых
#
#    salary_min salary_max salary_currency
# 0      90 000       None            руб.
# 1      40 000     60 000            руб.
# 2        None    240 000            руб.
# 3        None    450 000            руб.
# 4       2 000      4 000             USD
# 5     150 000       None            руб.
# 6     180 000    250 000            руб.
# 7       3 000      6 500             USD
# 8        None       None            None
# 9      70 000    105 000            руб.
# 10  1 000 000       None             KZT
# 11    160 000       None            руб.
# 12    180 000    250 000            руб.
# 13       None       None            None
# 14       None       None            None
# 15    150 000    180 000            руб.
# 16    100 000       None            руб.
# 17    100 000    200 000            руб.
# 18    120 000    240 000            руб.
# 19     30 000     80 000            руб.
# 20       None    300 000            руб.
# 21    100 000    150 000            руб.
# 22    240 000       None            руб.
# 23    100 000       None            руб.
# 24       None       None            None
# 25     60 000    120 000            руб.
# 26    250 000       None            руб.
# 27       None    350 000            руб.
# 28       None    450 000            руб.
# 29      4 000       None             EUR
# 30    150 000       None            руб.
# 31       None       None            None
# 32     50 000       None            руб.
# 33    150 000    230 000            руб.
# 34       None       None            None
# 35    200 000       None            руб.
# 36    100 000    150 000            руб.
# 37       None       None            None
# 38       None    250 000             KZT
# 39       None       None            None

# %%
# Функция запроса контента HTML-страницы SuperJob:
def superjob_get_content(response):
    soup = bs(response, 'lxml')
    items = soup.find_all('div', {'class': 'f-test-vacancy-item'})

    sj_vacancy = []
    for item in items:
        sj_vacancy.append(
            {'site': 'SuperJob',  # Название сайта
             'title': item.find('a').get_text(),  # Название вакансии
             'link': item.find('a').get('href'),  # Ссылка на вакансию
             'salary': item.find('div', {'class': 'f-test-text-company-item-salary'}),  # Зарплата
             'city': item.find('span', {'class': 'f-test-text-company-item-location'}),  # Город
             'organization': item.find('span', {'class': 'f-test-text-vacancy-item-company-name'}), # Название компании
             'note': item.find('span', {'class': 'f-test-badge'})})  # Примечание

   # Упорядочение полученных данных:
    for v in sj_vacancy:
        # Link
        v['link'] = HOST_SJ + v['link']
        # Salary
        if v['salary'] != None:
            v['salary'] = v['salary'].get_text()
        try:
            v['salary'] = v['salary'].text
        except:
            if v['salary'] != 'По договорённости':
                salary_list = v['salary'].split('\xa0')
            if salary_list[0] == 'от':
                v['salary_min'] = salary_list[1] + salary_list[2]
                v['salary_max'] = None
            elif salary_list[0] == 'до':
                v['salary_min'] = None
                v['salary_max'] = salary_list[1] + salary_list[2]
            elif len(salary_list) == 3:
                v['salary_min'] = salary_list[0] + salary_list[1]
                v['salary_max'] = salary_list[0] + salary_list[1]
            else:
                v['salary_min'] = salary_list[0] + salary_list[1]
                v['salary_max'] = salary_list[2] + salary_list[3]
            v['salary_currency'] = salary_list[-1].split('/')[0]
        else:
            v['salary_min'] = None
            v['salary_max'] = None
            v['salary_currency'] = None
        v.pop('salary')
        # City
        if v['city'] != None:
            v['city'] = v['city'].get_text()
        # Organization
        if v['organization'] != None:
            v['organization'] = v['organization'].get_text()
        # Note
        if v['note'] != None:
            v['note'] = v['note'].get_text()
        
    return sj_vacancy

# %%
# Главная функция парсинга сайта SuperJob:
def parser_sj():
    POST = str(input('Введите название вакансии для парсинга: '))
    PAGES = int(input('Количество страниц для парсинга: '))
    html = get_html(URL_SJ)
    if html.status_code == 200:
        vacancy = []
        for page in range(1, PAGES + 1):
            print(f'Парсится sj, страница: {page}')
            html = get_html(URL_SJ, params = {'keywords': POST, 'page': page})
            vacancy.extend(superjob_get_content(html.text))
        sj_result = pd.DataFrame(vacancy)
    else:
        sj_result = html.status_code
    
    return sj_result

parser_sj()
# Out:
# Введите название вакансии для парсинга: Разработчик Python
# Количество страниц для парсинга: 2
# Парсится sj, страница: 1
# Парсится sj, страница: 2
#         site                                              title  \
# 0   SuperJob                                   IOS/QT developer
# 1   SuperJob  Инженер-программист (специалист по работе с МИ...
# 2   SuperJob                       Разработчик Web и приложений
# 3   SuperJob        Fullstack веб-разработчик middle (удаленно)
# 4   SuperJob  Специалист службы поддержки с техническими зна...
# 5   SuperJob  Специалист службы поддержки с техническими зна...
# 6   SuperJob  Специалист службы поддержки с техническими зна...
# 7   SuperJob  Специалист службы поддержки с техническими зна...
# 8   SuperJob  Специалист службы поддержки с техническими зна...
# 9   SuperJob  Специалист службы поддержки с техническими зна...
# 10  SuperJob  Специалист службы поддержки с техническими зна...
# 11  SuperJob  Специалист службы поддержки с техническими зна...
# 12  SuperJob  Специалист службы поддержки с техническими зна...
# 13  SuperJob  Специалист службы поддержки с техническими зна...
# 14  SuperJob  Специалист службы поддержки с техническими зна...
# 15  SuperJob  Специалист службы поддержки с техническими зна...
# 16  SuperJob  Специалист службы поддержки с техническими зна...
# 17  SuperJob  Специалист службы поддержки с техническими зна...
# 18  SuperJob  Специалист службы поддержки с техническими зна...
# 19  SuperJob  Специалист службы поддержки с техническими зна...
# 20  SuperJob  Специалист службы поддержки с техническими зна...
# 21  SuperJob  Специалист службы поддержки с техническими зна...
# 22  SuperJob  Специалист службы поддержки с техническими зна...
# 23  SuperJob  Специалист службы поддержки с техническими зна...
# 24  SuperJob  Специалист службы поддержки (с техническими зн...
# 25  SuperJob  Специалист службы поддержки с техническими зна...
# 26  SuperJob         Специалист службы поддержки (Яндекс.Поиск)
# 27  SuperJob  Специалист службы поддержки с техническими зна...
# 28  SuperJob  Специалист службы поддержки (с техническими зн...
# 29  SuperJob  Специалист службы поддержки с техническими зна...
# 30  SuperJob  Специалист службы поддержки с техническими зна...
# 31  SuperJob  Специалист службы поддержки с техническими зна...
# 32  SuperJob  Специалист службы поддержки с техническими зна...
# 33  SuperJob  Специалист службы поддержки с техническими зна...
# 34  SuperJob  Специалист службы поддержки с техническими зна...
# 14                   Оренбург                               Яндекс
# 15                       Тула                               Яндекс
# 16                      Курск                               Яндекс
# 17                 Ставрополь                               Яндекс
# 18                Севастополь                               Яндекс
# 19                       Сочи                               Яндекс
# 20                   Кемерово                               Яндекс
# 21                  Махачкала                               Яндекс
# 22                      Томск                               Яндекс
# 23                Владивосток                               Яндекс
# 24                Владивосток                               Яндекс
# 25                Владивосток                               Яндекс
# 26                Владивосток                               Яндекс
# 27                Владивосток                               Яндекс
# 28                Владивосток                               Яндекс
# 29                Владивосток                               Яндекс
# 30                Владивосток                               Яндекс
# 31                Владивосток                               Яндекс
# 32                   Тольятти                               Яндекс
# 33                     Ижевск                               Яндекс
# 34                    Барнаул                               Яндекс
# 35                  Ульяновск                               Яндекс
# 36                    Иркутск                               Яндекс
# 37                  Хабаровск                               Яндекс
# 38                  Ярославль                               Яндекс
# 39                   Улан-Удэ                               Яндекс
#
#                  note salary_min salary_max salary_currency
# 0    Удаленная работа     400000   — 420000               ₽
# 1    Удаленная работа      50000    — 60000               ₽
# 2                None      80000   — 100000               ₽
# 3   Отклик без резюме      40000       None               ₽
# 4       Опыт не нужен      15000       None               ₽
# 5       Опыт не нужен      15000       None               ₽
# 6       Опыт не нужен      15000       None               ₽
# 7       Опыт не нужен      15000       None               ₽
# 8       Опыт не нужен      15000       None               ₽
# 9       Опыт не нужен      15000       None               ₽
# 10      Опыт не нужен      15000       None               ₽
# 11      Опыт не нужен      15000       None               ₽
# 12      Опыт не нужен      15000       None               ₽
# 13      Опыт не нужен      15000       None               ₽
# 14      Опыт не нужен      15000       None               ₽
# 15      Опыт не нужен      15000       None               ₽
# 16      Опыт не нужен      15000       None               ₽
# 17      Опыт не нужен      15000       None               ₽
# 18      Опыт не нужен      15000       None               ₽
# 19      Опыт не нужен      15000       None               ₽
# 20      Опыт не нужен      15000       None               ₽
# 21      Опыт не нужен      15000       None               ₽
# 22      Опыт не нужен      15000       None               ₽
# 23   Удаленная работа      15000       None               ₽
# 24  Отклик без резюме      15000       None               ₽
# 25      Опыт не нужен      15000       None               ₽
# 26      Опыт не нужен      15000       None               ₽
# 27   Удаленная работа      15000       None               ₽
# 28      Опыт не нужен      15000       None               ₽
# 29   Удаленная работа      15000       None               ₽
# 30   Удаленная работа      15000       None               ₽
# 31      Опыт не нужен      15000       None               ₽
# 32      Опыт не нужен      15000       None               ₽
# 33      Опыт не нужен      15000       None               ₽
# 34      Опыт не нужен      15000       None               ₽
# 35      Опыт не нужен      15000       None               ₽
# 36      Опыт не нужен      15000       None               ₽
# 37      Опыт не нужен      15000       None               ₽
# 38      Опыт не нужен      15000       None               ₽
# 39      Опыт не нужен      15000       None               ₽

# %%
# Функция объединения полученных результатов c двух сайтов:
def main_parsing():
    post = str(input('Введите название вакансии для парсинга: '))
    pages = int(input('Введите количество страниц для парсинга: '))
    HH_HTML = get_html(URL_HH)
    SJ_HTML = get_html(URL_SJ)

    if HH_HTML.status_code == 200 and SJ_HTML.status_code == 200:
        vacancy = []
        for page in range(1, pages + 1):
            print(f'Парсится общая информация, страница: {page}')
            hh = get_html(URL_HH, params = {'text': post, 'page': page})
            sj = get_html(URL_SJ, params = {'keywords': post, 'page': page})
            vacancy.extend(get_hh_content(hh.text) + superjob_get_content(sj.text))
        result = pd.DataFrame(vacancy)
    else:
        print('error')
    
    return result

# %%
# Вывод общей таблицы:
vacancyDF = main_parsing()
vacancyDF
# Out:
# Введите название вакансии для парсинга: Разработчик Python
# Введите количество страниц для парсинга: 1
# Парсится общая информация, страница: 1
#           site                                              title  \
# 0   HeadHanter                     Python-разработчик в R&D отдел
# 1   HeadHanter                                 Программист Python
# 2   HeadHanter                        Python разработчик (Django)
# 3   HeadHanter                                 Программист Python
# 4   HeadHanter                   Senior Python developer (Django)
# 5   HeadHanter                            Middle Python Developer
# 6   HeadHanter                                 Разработчик Python
# 7   HeadHanter  Python разработчик на внутренний проект (удалё...
# 8   HeadHanter                                    Python Engineer
# 9   HeadHanter       Разработчик Python (искусственный интеллект)
# 10  HeadHanter                        Программист Python (middle)
# 11  HeadHanter                    Middle Backend Python Developer
# 12  HeadHanter                   Middle Python developer (Казань)
# 13  HeadHanter                      Python разработчик (удалённо)
# 14  HeadHanter                                 Разработчик Python
# 15  HeadHanter                                 Разработчик Python
# 16  HeadHanter                        Разработчик бэкэнд (Python)
# 17  HeadHanter           Разработчик (Backend developer / Python)
# 18  HeadHanter             Backend-разработчик / Python developer
# 19  HeadHanter                                   Python developer
# 20    SuperJob                                   IOS/QT developer
# 21    SuperJob  Инженер-программист (специалист по работе с МИ...
# 22    SuperJob                       Разработчик Web и приложений
# 23    SuperJob        Fullstack веб-разработчик middle (удаленно)
# 24    SuperJob  Специалист службы поддержки с техническими зна...
# 25    SuperJob  Специалист службы поддержки с техническими зна...
# 26    SuperJob  Специалист службы поддержки с техническими зна...
# 27    SuperJob  Специалист службы поддержки с техническими зна...
# 28    SuperJob  Специалист службы поддержки с техническими зна...
# 29    SuperJob  Специалист службы поддержки с техническими зна...
# 30    SuperJob  Специалист службы поддержки с техническими зна...
# 31    SuperJob  Специалист службы поддержки с техническими зна...
# 32    SuperJob  Специалист службы поддержки с техническими зна...
# 33    SuperJob  Специалист службы поддержки с техническими зна...
# 34    SuperJob  Специалист службы поддержки с техническими зна...
# 35    SuperJob  Специалист службы поддержки с техническими зна...
# 36    SuperJob  Специалист службы поддержки с техническими зна...
# 37    SuperJob  Специалист службы поддержки с техническими зна...
# 38    SuperJob  Специалист службы поддержки с техническими зна...
# 39    SuperJob  Специалист службы поддержки с техническими зна...
# 40    SuperJob  Специалист службы поддержки с техническими зна...
# 41    SuperJob  Специалист службы поддержки с техническими зна...
# 42    SuperJob  Специалист службы поддержки с техническими зна...
# 43    SuperJob  Специалист службы поддержки с техническими зна...
# 44    SuperJob  Специалист службы поддержки (с техническими зн...
# 45    SuperJob  Специалист службы поддержки с техническими зна...
# 46    SuperJob         Специалист службы поддержки (Яндекс.Поиск)
# 47    SuperJob  Специалист службы поддержки с техническими зна...
# 48    SuperJob  Специалист службы поддержки (с техническими зн...
# 49    SuperJob  Специалист службы поддержки с техническими зна...
# 50    SuperJob  Специалист службы поддержки с техническими зна...
# 51    SuperJob  Специалист службы поддержки с техническими зна...
# 0                        None    100 000    150 000            руб.
# 1                        None     90 000       None            руб.
# 2                        None     40 000     60 000            руб.
# 3               Можно из дома       None    240 000            руб.
# 4               Можно из дома       None    450 000            руб.
# 5                        None      2 000      4 000             USD
# 6                        None    150 000       None            руб.
# 7               Можно из дома    180 000    250 000            руб.
# 8               Можно из дома      3 000      6 500             USD
# 9               Можно из дома       None       None            None
# 10              Можно из дома     70 000    105 000            руб.
# 11                       None  1 000 000       None             KZT
# 12                       None    160 000       None            руб.
# 13              Можно из дома    180 000    250 000            руб.
# 14              Можно из дома       None       None            None
# 15                       None       None       None            None
# 16                       None    150 000    180 000            руб.
# 17              Можно из дома    100 000       None            руб.
# 18                       None    100 000    200 000            руб.
# 19  Откликнитесь среди первых    120 000    240 000            руб.
# 20           Удаленная работа     400000   — 420000               ₽
# 21           Удаленная работа      50000    — 60000               ₽
# 22                       None      80000   — 100000               ₽
# 23          Отклик без резюме      40000       None               ₽
# 24              Опыт не нужен      15000       None               ₽
# 25              Опыт не нужен      15000       None               ₽
# 26              Опыт не нужен      15000       None               ₽
# 27              Опыт не нужен      15000       None               ₽
# 28              Опыт не нужен      15000       None               ₽
# 29              Опыт не нужен      15000       None               ₽
# 30              Опыт не нужен      15000       None               ₽
# 31              Опыт не нужен      15000       None               ₽
# 32              Опыт не нужен      15000       None               ₽
# 33              Опыт не нужен      15000       None               ₽
# 34              Опыт не нужен      15000       None               ₽
# 35              Опыт не нужен      15000       None               ₽
# 36              Опыт не нужен      15000       None               ₽
# 37              Опыт не нужен      15000       None               ₽
# 38              Опыт не нужен      15000       None               ₽
# 39              Опыт не нужен      15000       None               ₽
# 40              Опыт не нужен      15000       None               ₽
# 41              Опыт не нужен      15000       None               ₽
# 42              Опыт не нужен      15000       None               ₽
# 43           Удаленная работа      15000       None               ₽
# 44          Отклик без резюме      15000       None               ₽
# 45              Опыт не нужен      15000       None               ₽
# 46              Опыт не нужен      15000       None               ₽
# 47           Удаленная работа      15000       None               ₽
# 48              Опыт не нужен      15000       None               ₽
# 49           Удаленная работа      15000       None               ₽
# 50           Удаленная работа      15000       None               ₽
# 51              Опыт не нужен      15000       None               ₽
# 52              Опыт не нужен      15000       None               ₽
# 53              Опыт не нужен      15000       None               ₽
# 54              Опыт не нужен      15000       None               ₽
# 55              Опыт не нужен      15000       None               ₽
# 56              Опыт не нужен      15000       None               ₽
# 57              Опыт не нужен      15000       None               ₽
# 58              Опыт не нужен      15000       None               ₽
# 59              Опыт не нужен      15000       None               ₽

# %%
# Просмотр информации общей таблицы:
vacancyDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   site             60 non-null     object
#  1   title            60 non-null     object
#  2   link             60 non-null     object
#  3   city             60 non-null     object
#  4   organization     59 non-null     object
#  5   note             49 non-null     object
#  6   salary_min       55 non-null     object
#  7   salary_max       15 non-null     object
#  8   salary_currency  57 non-null     object
# dtypes: object(9)
# memory usage: 4.3+ KB

# %%
# Сохранение общих данных в файл .csv:
vacancyDF.to_csv('vacancy.csv', index = False, encoding = 'utf8')

# %%
# Проверка обратным преобразованием:
#df = pd.read_csv('vacancy.csv')
#df

# %% [markdown]
# ---
#
# END
